# %%
from shapely.geometry import shape,Polygon,MultiPolygon,mapping
import geopandas as gpd
from shapely.validation import make_valid
from osgeo import gdal
from osgeo import ogr
import pandas as pd

# %%
g1 = gpd.GeoDataFrame.from_file("gaul2015-2014_adm2.shp")

g2 = gpd.GeoDataFrame.from_file("WA_200907_CS.shp")

# %%
combined = gpd.sjoin(g1,g2,how="right",op="intersects")
combined
# Out:
# C:\Users\ASUS\anaconda3\envs\plotlyenv\lib\site-packages\IPython\core\interactiveshell.py:3337: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#     index_left  adm2_code       adm2_name  str2_year exp2_year  adm1_code  \
# 0         1558    65360.0           Arada        NaN      None      870.0
# 0         1559    65415.0             Bol        NaN      None      875.0
# 0         1563    65579.0       Massakory        NaN      None    12912.0
# 0         1564    65636.0          Ngouri        NaN      None    12915.0
# 0         1567    65353.0  Abou-charib-ii     2000.0      None      870.0
# ..         ...        ...             ...        ...       ...        ...
# 2         5651    19532.0       Ouad Naga        NaN      None     2016.0
# 2         5657    19375.0          Menaka        NaN      None     1927.0
# ...

# %%
df = gpd.GeoDataFrame(combined, geometry='geometry')
#df.to_file(r'C:\Users\ASUS\Desktop\testi\gaul\my_shapefile.shp')
